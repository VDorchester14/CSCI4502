# %% [markdown]
# Vail Dorchester

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
path = './HD.csv'
df = pd.read_csv(path)

# %%
plt.plot(df['date'], df['high'])
plt.show()

# %%
df['date'] = pd.to_datetime(df['date'])
#df = df.sort_values(['date'])
df.head()
# Out:
#           date   close  volume    open    high      low
# 365   9/9/2016  158.49  252247  161.20  162.18  158.400
# 618   9/9/2015  106.97  135782  108.90  110.14  106.690
# 870   9/9/2014   76.89  122490   77.38   77.68   76.790
# 1122  9/9/2013   69.31   99989   68.71   69.64   68.500
# 114   9/8/2017  227.73  191533  225.91  229.16  225.312
